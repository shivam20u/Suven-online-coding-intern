# %% [markdown]
# #        Performing Analysis of Meteorological Data

# %% [markdown]
# #  Import Libraries & Data

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from matplotlib import style

# %%
weather = pd.read_csv('weatherHistory.csv')
weather
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
weather.head(10)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6  2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7  2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8  2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9  2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# ...

# %%
weather.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
weather.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
weather.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df = weather[['Formatted Date','Apparent Temperature (C)','Humidity']]
df.head(10)
# Out:
#                   Formatted Date  Apparent Temperature (C)  Humidity
# 0  2006-04-01 00:00:00.000 +0200                  7.388889      0.89
# 1  2006-04-01 01:00:00.000 +0200                  7.227778      0.86
# 2  2006-04-01 02:00:00.000 +0200                  9.377778      0.89
# 3  2006-04-01 03:00:00.000 +0200                  5.944444      0.83
# 4  2006-04-01 04:00:00.000 +0200                  6.977778      0.83
# 5  2006-04-01 05:00:00.000 +0200                  7.111111      0.85
# 6  2006-04-01 06:00:00.000 +0200                  5.522222      0.95
# 7  2006-04-01 07:00:00.000 +0200                  6.527778      0.89
# 8  2006-04-01 08:00:00.000 +0200                 10.822222      0.82
# 9  2006-04-01 09:00:00.000 +0200                 13.772222      0.72

# %% [markdown]
# # Resample data from hourly to month wise

# %%
df['Formatted Date']=pd.to_datetime(df['Formatted Date'], utc=True)
df=df.set_index('Formatted Date')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1 = df[['Apparent Temperature (C)','Humidity']].resample('MS').mean()
df1
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-01 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-01 00:00:00+00:00                  1.969780  0.778737
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625
# ...                                             ...       ...
# 2016-08-01 00:00:00+00:00                 21.383094  0.674046
# 2016-09-01 00:00:00+00:00                 18.355833  0.688833
# 2016-10-01 00:00:00+00:00                  8.923947  0.799906
# 2016-11-01 00:00:00+00:00                  3.048627  0.848472
# 2016-12-01 00:00:00+00:00                 -2.017272  0.887981
#
# [133 rows x 2 columns]

# %% [markdown]
# # Analysis plots of Temperature & Humidity over the range of years in the dataset
# Variation in Apparent Temperature & Humidity with time (in years)

# %%
plt.figure(figsize=(16,9))
plt.plot(df1['Humidity'],label='Humidity',color='orange', linewidth = 3)
plt.plot(df1['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='black', linewidth = 2)
plt.title('Appenrent Temperature & Humidity variation with time(in years)')
plt.legend(loc= 3,fontsize = 16)
plt.show()

# %% [markdown]
# # Humidity month-wise with respect to time (in years)

# %%
plt.figure(figsize=(17,12))
jan=df1[df1.index.month ==1]
feb=df1[df1.index.month ==2]
mar=df1[df1.index.month ==3]
apr=df1[df1.index.month ==4]
may=df1[df1.index.month ==5]
jun=df1[df1.index.month ==6]
jul=df1[df1.index.month ==7]
aug=df1[df1.index.month ==8]
sep=df1[df1.index.month ==9]
octo=df1[df1.index.month ==10]
nov=df1[df1.index.month ==11]
dec=df1[df1.index.month ==12]
plt.plot(jan['Humidity'],label = 'January',marker ="o",color = 'red',markersize = 10)
plt.plot(feb['Humidity'],label = 'February', color = 'green',marker ="o",markersize = 10)
plt.plot(mar['Humidity'],label = 'March', color = 'teal',marker ="o",markersize = 10)
plt.plot(apr['Humidity'],label = 'April', color = 'maroon',marker ="o",markersize = 10)
plt.plot(may['Humidity'],label = 'May', color = 'indigo',marker ="o",markersize = 10)
plt.plot(jun['Humidity'],label = 'June', color = 'yellow',marker ="o",markersize = 10)
plt.plot(jul['Humidity'],label = 'July', color = 'purple',marker ="o",markersize = 10)
plt.plot(aug['Humidity'],label = 'August', color = 'orange',marker ="o",markersize = 10)
plt.plot(sep['Humidity'],label = 'September', color = 'Plum',marker ="o",markersize = 10)
plt.plot(octo['Humidity'],label = 'October', color = 'blue',marker ="o",markersize = 10)
plt.plot(nov['Humidity'],label = 'November', color = 'black',marker ="o",markersize = 10)
plt.plot(dec['Humidity'],label = 'December', color = 'Olive',marker ="o",markersize = 10)
plt.title('Humidity month-wise with respect to time (in years)',fontsize = 15)
plt.legend(loc= 4,fontsize = 13)
plt.show()

# %% [markdown]
# # Average Apparent Temperature month-wise with respect to year

# %%
plt.figure(figsize=(20,15))
jan=df1[df1.index.month ==1]
feb=df1[df1.index.month ==2]
mar=df1[df1.index.month ==3]
apr=df1[df1.index.month ==4]
may=df1[df1.index.month ==5]
jun=df1[df1.index.month ==6]
jul=df1[df1.index.month ==7]
aug=df1[df1.index.month ==8]
sep=df1[df1.index.month ==9]
octo=df1[df1.index.month ==10]
nov=df1[df1.index.month ==11]
dec=df1[df1.index.month ==12]
plt.plot(jan['Apparent Temperature (C)'],label = 'January',marker ="o",color = 'red',markersize = 10)
plt.plot(feb['Apparent Temperature (C)'],label = 'February', color = 'green',marker ="o",markersize = 10)
plt.plot(mar['Apparent Temperature (C)'],label = 'March', color = 'teal',marker ="o",markersize = 10)
plt.plot(apr['Apparent Temperature (C)'],label = 'April', color = 'maroon',marker ="o",markersize = 10)
plt.plot(may['Apparent Temperature (C)'],label = 'May', color = 'indigo',marker ="o",markersize = 10)
plt.plot(jun['Apparent Temperature (C)'],label = 'June', color = 'yellow',marker ="o",markersize = 10)
plt.plot(jul['Apparent Temperature (C)'],label = 'July', color = 'purple',marker ="o",markersize = 10)
plt.plot(aug['Apparent Temperature (C)'],label = 'August', color = 'orange',marker ="o",markersize = 10)
plt.plot(sep['Apparent Temperature (C)'],label = 'September', color = 'Plum',marker ="o",markersize = 10)
plt.plot(octo['Apparent Temperature (C)'],label = 'October', color = 'blue',marker ="o",markersize = 10)
plt.plot(nov['Apparent Temperature (C)'],label = 'November', color = 'black',marker ="o",markersize = 10)
plt.plot(dec['Apparent Temperature (C)'],label = 'December', color = 'Olive',marker ="o",markersize = 10)
plt.title('Average Apparent Temperature month-wise with respect to year')
plt.legend(loc= 4,fontsize = 15)
plt.show()

# %% [markdown]
# # Monthly analysis for all 12 months over the 10 year period
# Plots of all the months spanning over 10 years

# %%
plt.figure(figsize = (20,20))

plt.subplot(4,3,1)
jan=df1[df1.index.month ==1]
plt.plot(jan['Humidity'],label = 'Humidity', color = 'green',marker = "o")
plt.plot(jan['Apparent Temperature (C)'], label = 'Apparent Temperature (C)', color= 'maroon',marker = "o")
plt.title(' Plot of Appenrent Temperature & Humidity with year for January ',fontsize=10)
plt.legend(loc=6,fontsize =14)

plt.subplot(4,3,2)
feb=df1[df1.index.month ==2]
plt.plot(feb['Humidity'],label = 'Humidity', color = 'green',marker = "o")
plt.plot(feb['Apparent Temperature (C)'], label = 'Apparent Temperature (C)', color= 'maroon',marker = "o")
plt.title(' Plot of Appenrent Temperature & Humidity with year for February ',fontsize=10)
plt.legend(loc=6,fontsize =14)

plt.subplot(4,3,3)
mar=df1[df1.index.month ==3]
plt.plot(mar['Humidity'],label = 'Humidity', color = 'green',marker = "o")
plt.plot(mar['Apparent Temperature (C)'], label = 'Apparent Temperature (C)', color='maroon',marker = "o")
plt.title(' Plot of Appenrent Temperature & Humidity with year for March ',fontsize=10)
plt.legend(loc=6,fontsize =14)

plt.subplot(4,3,4)
apr=df1[df1.index.month ==4]
plt.plot(apr['Humidity'],label = 'Humidity', color = 'green',marker = "o")
plt.plot(apr['Apparent Temperature (C)'], label = 'Apparent Temperature (C)', color= 'maroon',marker = "o")
plt.title(' Plot of Appenrent Temperature & Humidity with year for April ',fontsize=10)
plt.legend(loc=6,fontsize =14)

plt.subplot(4,3,5)
may=df1[df1.index.month ==5]
plt.plot(may['Humidity'],label = 'Humidity', color = 'green',marker = "o")
plt.plot(may['Apparent Temperature (C)'], label = 'Apparent Temperature (C)', color= 'maroon',marker = "o")
plt.title(' Plot of Appenrent Temperature & Humidity with year for May ',fontsize=10)
plt.legend(loc=6,fontsize =14)

plt.subplot(4,3,6)
jun=df1[df1.index.month ==6]
plt.plot(jun['Humidity'],label = 'Humidity', color = 'green',marker = "o")
plt.plot(jun['Apparent Temperature (C)'], label = 'Apparent Temperature (C)', color= 'maroon',marker = "o")
plt.title(' Plot of Appenrent Temperature & Humidity with year for June',fontsize=10)
plt.legend(loc=6,fontsize =14)

plt.subplot(4,3,7)
jul=df1[df1.index.month ==7]
plt.plot(jul['Humidity'],label = 'Humidity', color = 'green',marker = "o")
plt.plot(jul['Apparent Temperature (C)'], label = 'Apparent Temperature (C)', color= 'maroon',marker = "o")
plt.title(' Plot of Appenrent Temperature & Humidity with year for July',fontsize=10)
plt.legend(loc=6,fontsize =14)

plt.subplot(4,3,8)
aug=df1[df1.index.month ==8]
plt.plot(aug['Humidity'],label = 'Humidity', color = 'green',marker = "o")
plt.plot(aug['Apparent Temperature (C)'], label = 'Apparent Temperature (C)', color= 'maroon',marker = "o")
plt.title(' Plot of Appenrent Temperature & Humidity with year for August ',fontsize=10)
plt.legend(loc=6,fontsize =14)

plt.subplot(4,3,9)
sept=df1[df1.index.month ==9]
plt.plot(sept['Humidity'],label = 'Humidity', color = 'green',marker = "o")
plt.plot(sept['Apparent Temperature (C)'], label = 'Apparent Temperature (C)', color= 'maroon',marker = "o")
plt.title(' Plot of Appenrent Temperature & Humidity with year for September ',fontsize=10)
plt.legend(loc=6,fontsize =14)

plt.subplot(4,3,10)
octo=df1[df1.index.month ==10]
plt.plot(octo['Humidity'],label = 'Humidity', color = 'green',marker = "o")
plt.plot(octo['Apparent Temperature (C)'], label = 'Apparent Temperature (C)', color= 'maroon',marker = "o")
plt.title(' Plot of Appenrent Temperature & Humidity with year for October ',fontsize=10)
plt.legend(loc=6,fontsize =14)

plt.subplot(4,3,11)
nov=df1[df1.index.month ==11]
plt.plot(nov['Humidity'],label = 'Humidity', color = 'green',marker = "o")
plt.plot(nov['Apparent Temperature (C)'], label = 'Apparent Temperature (C)', color= 'maroon',marker = "o")
plt.title(' Plot of Appenrent Temperature & Humidity with year for November ',fontsize=10)
plt.legend(loc=6,fontsize =14)

plt.subplot(4,3,12)
dec=df1[df1.index.month ==12]
plt.plot(dec['Humidity'],label = 'Humidity', color = 'green',marker = "o")
plt.plot(dec['Apparent Temperature (C)'], label = 'Apparent Temperature (C)', color='maroon',marker = "o")
plt.title('Plot of Appenrent Temperature. & Humidity with year for December ',fontsize=10)
plt.legend(loc=6,fontsize =14)

plt.show()

# %%
import scipy.stats as stats

# %%
x=df1['Apparent Temperature (C)']
y=df1['Humidity']
test=stats.ttest_rel(a,b)
pvalue=test[1]
print(pvalue)
# Out:
# 6.686806828886333e-24

# %%
if pvalue>0.05:
    print("Accept Null Hypothesis")
else:
    print("Reject Null Hypothesis")
# Out:
# Reject Null Hypothesis
